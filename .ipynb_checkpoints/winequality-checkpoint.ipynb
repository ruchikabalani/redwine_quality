# %% [markdown]
# # Import Required Packagesrting Libraries

# %%
from pathlib import Path # to interact with file system.

import numpy as np # for working with arrays.
import pandas as pd # for working with data frames (tables).

from sklearn.model_selection import train_test_split # for data partition.
from sklearn.metrics import r2_score # to identify r_squared for regression model.
from sklearn.linear_model import LinearRegression # for linear regression model. 
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn import neighbors 
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.metrics import mean_squared_error 

import statsmodels.formula.api as sm
from math import sqrt

from dmba import regressionSummary, exhaustive_search
from dmba import backward_elimination, forward_selection, stepwise_selection
from dmba import adjusted_r2_score, AIC_score, BIC_score

# %matplotlib inline 
import matplotlib.pylab as plt # for building and showing graphs.

# %% [markdown]
# # Upload data set for analysis.

# %%
# Create a data frame in Python using winequality-red.csv file.
winequality_df = pd.read_csv('data/winequality-red.csv')

# %%
# Determine and display dimensions of data frame. 
print('Number of rows and columns in data set:', 
      winequality_df.shape )
# Out:
# Number of rows and columns in data set: (1599, 12)

# %%
# Display the first 5 rows of the dataframe. 
winequality_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# Display the last five rows of the dataframe.
winequality_df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %%
# Display the column names.
print('Original column titles:')
winequality_df.columns
# Out:
# Original column titles:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# # Data exploration, cleanup, and preprocessing.

# %%
# We strip trail spaces and replace the remaining spaces 
# with an underscore '_'. 
print('Modified column titles with no space and one word for titles:')
winequality_df.columns = [s.strip().replace(' ', '_') for s in winequality_df.columns]
winequality_df.columns
# Out:
# Modified column titles with no space and one word for titles:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#Detect duplicate values
duplicaterow = winequality_df[winequality_df.duplicated()]
duplicaterow
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 11                   17.0                 102.0  0.99780  3.35       0.80
# 27                   10.0                  37.0  0.99660  3.17       0.91
# 40                   12.0                  87.0  0.99780  3.33       0.83
# 65                    4.0                  11.0  0.99620  3.41       0.39
# ...                   ...                   ...      ...   ...        ...
# 1563                 12.0                  20.0  0.99546  3.29       0.54
# 1564                 12.0                  20.0  0.99546  3.29       0.54
# 1567                 12.0                  20.0  0.99546  3.29       0.54
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1596                 29.0                  40.0  0.99574  3.42       0.75
#
#       alcohol  quality
# 4         9.4        5
# 11       10.5        5
# 27        9.5        5
# 40       10.5        5
# 65       10.9        5
# ...       ...      ...
# 1563     10.1        5
# 1564     10.1        5
# 1567     10.1        5
# 1581     11.3        5
# 1596     11.0        6
#
# [240 rows x 12 columns]

# %%
#Remove duplicate values
winequality_df = winequality_df.drop_duplicates()
winequality_df.shape
# Out:
# (1359, 12)

# %%
#Display count of missing values in other columns
winequality_df.isna().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Use describe() function to display column statistics
# for the entire data set. 
np.round(winequality_df.describe(), decimals=2)
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count        1359.00           1359.00      1359.00         1359.00
# mean            8.31              0.53         0.27            2.52
# std             1.74              0.18         0.20            1.35
# min             4.60              0.12         0.00            0.90
# 25%             7.10              0.39         0.09            1.90
# 50%             7.90              0.52         0.26            2.20
# 75%             9.20              0.64         0.43            2.60
# max            15.90              1.58         1.00           15.50
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density       pH  \
# count    1359.00              1359.00               1359.00  1359.00  1359.00
# mean        0.09                15.89                 46.83     1.00     3.31
# std         0.05                10.45                 33.41     0.00     0.16
# min         0.01                 1.00                  6.00     0.99     2.74
# 25%         0.07                 7.00                 22.00     1.00     3.21
# 50%         0.08                14.00                 38.00     1.00     3.31
# 75%         0.09                21.00                 63.00     1.00     3.40
# max         0.61                72.00                289.00     1.00     4.01
#
#        sulphates  alcohol  quality
# count    1359.00  1359.00  1359.00
# mean        0.66    10.43     5.62
# std         0.17     1.08     0.82
# min         0.33     8.40     3.00
# 25%         0.55     9.50     5.00
# 50%         0.62    10.20     6.00
# 75%         0.73    11.10     6.00
# max         2.00    14.90     8.00

# %%
# Display column data types. 
winequality_df.dtypes
# Out:
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# # Partition

# %%
# Identify predictors and outcome of the regression model.
predictors = ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide','total_sulfur_dioxide', 'density', 'pH', 'sulphates',
               'alcohol']
outcome = 'quality'

print('Predictor Variables:', predictors)
print('Outcome Variable:', outcome)
# Out:
# Predictor Variables: ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol']
# Outcome Variable: quality

# %%
# Identify X and y variables for regression and partition data using 80% of records for training
# and 20% for validation (test_size=0.2). 
X = winequality_df[predictors]
y = winequality_df[outcome]
train_X, valid_X, train_y, valid_y = train_test_split(X, y, test_size=0.2, random_state=1)
print('Number of rows and columns of predictors in training data set:', 
      train_X.shape)
print('Number of rows and columns of predictors in validation data set:', 
      valid_X.shape)
print('Number of rows of outcome variable in training data set:', 
      train_y.shape)
print('Number of rows of outcome variable in validation data set:', 
      valid_y.shape)
# Out:
# Number of rows and columns of predictors in training data set: (1087, 11)
# Number of rows and columns of predictors in validation data set: (272, 11)
# Number of rows of outcome variable in training data set: (1087,)
# Number of rows of outcome variable in validation data set: (272,)

# %% [markdown]
# # Develop multiple linear regression model

# %%
# Create multiple linear regression model using X and y and LinearRegression() function from sklearn (scikit-learn) 
# library.
redwine_lm = LinearRegression()
redwine_lm.fit(train_X, train_y)

# Display intercept and regression coefficients. Round them to 2 decimals.
print('Regression Model for Red Wine Quality Training Set')
print()
print('Intercept: ', np.round(redwine_lm.intercept_, 2))
print(pd.DataFrame({'Predictor': X.columns, 'Coefficient': np.round(redwine_lm.coef_, 2)}))
# Out:
# Regression Model for Red Wine Quality Training Set
#
# Intercept:  4.11
#                Predictor  Coefficient
# 0          fixed_acidity         0.01
# 1       volatile_acidity        -1.14
# 2            citric_acid        -0.19
# 3         residual_sugar        -0.00
# 4              chlorides        -1.56
# 5    free_sulfur_dioxide         0.01
# 6   total_sulfur_dioxide        -0.00
# 7                density         0.53
# 8                     pH        -0.62
# 9              sulphates         1.00
# 10               alcohol         0.30

# %%
# Use predict() to score (make) predictions for validation set.
redwine_lm_pred = redwine_lm.predict(valid_X)

# Develop and display data frame with actual values of MVALUE, scoring (predicted) results, and residuals.
# Use round() function to round vlaues in data frame to 2 decimals. 
print('Actual, Prediction, and Residual MVALUEs for Validation Set')
result = round(pd.DataFrame({'Actual': valid_y,'Predicted': redwine_lm_pred, 
                       'Residual': valid_y - redwine_lm_pred}), 2)
print(result.head(10))
# Out:
# Actual, Prediction, and Residual MVALUEs for Validation Set
#       Actual  Predicted  Residual
# 473        5       6.09     -1.09
# 1376       5       5.03     -0.03
# 533        6       6.79     -0.79
# 200        7       6.10      0.90
# 268        6       5.38      0.62
# 210        6       6.48     -0.48
# 906        5       5.66     -0.66
# 1093       7       6.57      0.43
# 947        7       6.51      0.49
# 867        6       6.09     -0.09

# %%
# Use predict() function to make predictions for training set.
pred_y = redwine_lm.predict(train_X)

# Develop and display data frame with actual values of quality, scoring (predicted) results, and residuals.
# Use round() function to round vlaues in data frame to 2 decimals. 
print('Actual, Prediction, and Residual quality for Training Set')
result = round(pd.DataFrame({'Actual': train_y,'Predicted': pred_y, 
                       'Residual': train_y - pred_y}), 2)
print(result.head(10))
# Out:
# Actual, Prediction, and Residual quality for Training Set
#       Actual  Predicted  Residual
# 1031       7       5.77      1.23
# 844        6       6.35     -0.35
# 38         4       4.37     -0.37
# 1384       5       4.89      0.11
# 611        5       5.60     -0.60
# 631        5       5.60     -0.60
# 7          7       5.28      1.72
# 816        6       5.68      0.32
# 1282       6       5.60      0.40
# 1081       7       5.77      1.23

# %%
# Use predict() function to make predictions for training set.
pred_y = redwine_lm.predict(train_X)

# Create prediction performance measures for training set.
r2 = round(r2_score(train_y, pred_y),3)
adj_r2 = round(adjusted_r2_score(train_y, pred_y, redwine_lm),3)
aic = round(AIC_score(train_y, pred_y, redwine_lm),2)
bic = round(BIC_score(train_y, pred_y, redwine_lm),2)

# Display prediction performance measures for training set.
print('Prediction Performance Measures for Training Set')
print('r2 : ', r2)
print('Adjusted r2 : ', adj_r2)
print('AIC : ', aic)
print('BIC : ', bic)
print() 

# Create prediction performance measures for validation set.
r2 = round(r2_score(valid_y, redwine_lm_pred),3)
adj_r2 = round(adjusted_r2_score(valid_y, redwine_lm_pred, redwine_lm),3)
aic = round(AIC_score(valid_y, redwine_lm_pred, redwine_lm),2)
bic = round(BIC_score(valid_y, redwine_lm_pred, redwine_lm),2)

# Display prediction performance measures for validation set.
print('Prediction Performance Measures for Validation Set')
print('r2 : ', r2)
print('adjusted r2 : ', adj_r2)
print('AIC : ', aic)
print('BIC : ', bic)
# Out:
# Prediction Performance Measures for Training Set
# r2 :  0.383
# Adjusted r2 :  0.377
# AIC :  2193.17
# BIC :  2258.06
#
# Prediction Performance Measures for Validation Set
# r2 :  0.257
# adjusted r2 :  0.225
# AIC :  578.82
# BIC :  625.69

# %%
# Display common accuracy measures for training set.
print('Accuracy Measures for Training Set - All Variables')
regressionSummary(train_y, pred_y)
print()

# Display common accuracy measures for validation set.
print('Accuracy Measures for Validation Set - All Variables')
regressionSummary(valid_y, redwine_lm_pred)
# Out:
# Accuracy Measures for Training Set - All Variables
#
# Regression statistics
#
#                       Mean Error (ME) : 0.0000
#        Root Mean Squared Error (RMSE) : 0.6557
#             Mean Absolute Error (MAE) : 0.5037
#           Mean Percentage Error (MPE) : -1.4578
# Mean Absolute Percentage Error (MAPE) : 9.2685
#
# Accuracy Measures for Validation Set - All Variables
#
# Regression statistics
#
#                       Mean Error (ME) : -0.0097
#        Root Mean Squared Error (RMSE) : 0.6685
#             Mean Absolute Error (MAE) : 0.5244
#           Mean Percentage Error (MPE) : -1.6084
# Mean Absolute Percentage Error (MAPE) : 9.7405

# %% [markdown]
# # Develop k-NN model with best value of k and make predictions for new records.

# %%
# Develop standardized (normalized) data for the training and 
# validation partitions for k-NN regressor model.

# Create scaler object using StandardScaler() function. 
scaler = StandardScaler()

# Transform training and validation predictors into scaled 
# (normalized) values (train_X_scaled), and create a data 
# frame based on the transformed values. 
train_X_scaled = scaler.fit_transform(train_X)

train_X_s = pd.DataFrame(train_X_scaled, 
                columns=['zfixed_acidity', 'zvolatile_acidity', 'zcitric_acid', 'zresidual_sugar', 
                         'zchlorides', 'zfree_sulfur_dioxide','ztotal_sulfur_dioxide', 'zdensity', 
                         'zpH', 'zsulphates','zalcohol'])

valid_X_scaled = scaler.fit_transform(valid_X)
valid_X_s = pd.DataFrame(valid_X_scaled,
                columns=['zfixed_acidity', 'zvolatile_acidity', 'zcitric_acid', 'zresidual_sugar', 
                         'zchlorides', 'zfree_sulfur_dioxide','ztotal_sulfur_dioxide', 'zdensity', 
                         'zpH', 'zsulphates','zalcohol'])

#Display training partition shape (number of records, number of columns)
print('Number of Records and Columns in Training and Validation Partitions')
print(train_X_s.shape, valid_X_s.shape)

# Display normalized training partition records. 
print()
print('Training Partition Records')
print(train_X_s)

#print()
#print('Validation Partition Records')
#print(valid_X_s)
# Out:
# Number of Records and Columns in Training and Validation Partitions
# (1087, 11) (272, 11)
#
# Training Partition Records
#       zfixed_acidity  zvolatile_acidity  zcitric_acid  zresidual_sugar  \
# 0          -0.585161           0.105472     -1.346903        -0.537148
# 1           0.894204          -1.516528      0.961892        -0.608418
# 2          -1.495540           3.241339     -0.936451        -0.750959
# 3          -0.698959           1.213839     -0.628612        -0.537148
# 4           2.771860          -0.813661      1.423651         0.104283
# ...              ...                ...           ...              ...
# 1082       -0.300668           0.213606     -0.936451        -0.180798
# 1083        1.064900          -1.300261      1.936716        -0.109528
# 1084       -0.698959          -2.003128      0.859279        -0.038258
# 1085       -0.243769          -0.975861      0.961892         0.745713
# 1086       -0.528263           0.105472     -0.423385        -0.537148
#
#       zchlorides  zfree_sulfur_dioxide  ztotal_sulfur_dioxide  zdensity  \
# 0       0.110363             -0.646403              -0.955220 -0.847300
# 1      -0.544375              0.948587              -0.141404 -0.441406
# 2       1.778891             -0.834049              -0.834655 -1.456140
# 3       0.406052              0.385649               1.124533 -0.425384
# 4      -0.143084             -1.021695              -0.925079  2.068724
# ...          ...                   ...                    ...       ...
# 1082   -0.481013              1.699170              -0.050980 -1.365348
# 1083   -0.269807             -0.927872              -0.894937 -0.574924
# 1084   -0.417652              0.104181              -0.472958 -1.840671
# 1085   -0.206446             -0.083465              -0.292110  0.306292
# 1086   -0.121963             -0.083465              -0.382534 -0.094261
#
#            zpH  zsulphates  zalcohol
# 0     0.274379   -0.453554  0.533966
# 1    -0.829288    1.056347  0.159481
# 2     1.248202   -1.057514 -0.589490
# 3    -0.764366   -0.936722 -0.870354
# 4    -2.127718   -0.695138 -0.963976
# ...        ...         ...       ...
# 1082  0.988516    0.512783  2.125529
# 1083 -0.569601   -0.151573  1.282937
# 1084  0.274379   -0.695138  1.844665
# 1085  0.274379    1.237535  2.219151
# 1086  1.183280    0.150407  0.065859
#
# [1087 rows x 11 columns]

# %%
# Develop k-NN regressor model using training partition for various
# values of k and then identify RMSE for each model 
# using validation partition.
results_rmse = [] #to store rmse values for different k
for k in range(1, 21):
    # Create k-NN model for different k in training partition.
    knn_model = neighbors.KNeighborsRegressor(n_neighbors = k)
    knn_model.fit(train_X_s, train_y) 
    
    # Make k-NN model predictions using validation partition.
    knn_pred = knn_model.predict(valid_X_s)
    
    # calculate RMSE for predictions in validation partition.
    RMSE = sqrt(mean_squared_error(valid_y, knn_pred))
    
    # Develop output resuts with each k and respective RMSE.
    results_rmse.append({
        'k': k,
        'RMSE': RMSE
    })
    
# Convert results_rmse to a pandas data frame and display 
# data frame. 
results = pd.DataFrame(results_rmse)
print(results)
# Out:
#      k      RMSE
# 0    1  0.853195
# 1    2  0.782389
# 2    3  0.750817
# 3    4  0.720785
# 4    5  0.704711
# 5    6  0.696411
# 6    7  0.689485
# 7    8  0.678628
# 8    9  0.676601
# 9   10  0.677419
# 10  11  0.674110
# 11  12  0.671627
# 12  13  0.675947
# 13  14  0.673981
# 14  15  0.672390
# 15  16  0.668231
# 16  17  0.666152
# 17  18  0.667033
# 18  19  0.662914
# 19  20  0.661737

# %%
# Develop and display Elbow chart to compare RMSE with 
# number of nearest neighbors, k, from 1 to 20. 
ax = results.plot(x='k', y='RMSE')
plt.xlabel('Number of Nearest Neighbors (k)')
plt.ylabel('RMSE')

plt.title('Elbow chart')
ax.legend().set_visible(False)
plt.show()

# %%
# Develop k-NN regressor model using KNeighborsRegressor()
# function and number of nearest neighbors, k = 17.
knn = neighbors.KNeighborsRegressor(n_neighbors=17)
knn.fit(train_X_s, train_y)
# Out:
# KNeighborsRegressor(n_neighbors=17)

# %%
# Make predictions using k-NN model. 
# Use predict() to score (make) predictions for validation set.
knn_valid_pred = knn.predict(valid_X_s)

# Develop and display data frame with actual values of Price,
# scoring (predicted) results, and residuals.
# Use round() function to round vlaues in data frame to 
# 2 decimals. 
print('Actual, Prediction, and Residual Prices for Validation Set')
result = round(pd.DataFrame({'Actual': valid_y,'Predicted': knn_valid_pred, 
                       'Residual': valid_y - knn_valid_pred}), 2)
print(result.head(10))
# Out:
# Actual, Prediction, and Residual Prices for Validation Set
#       Actual  Predicted  Residual
# 473        5       6.41     -1.41
# 1376       5       5.06     -0.06
# 533        6       6.41     -0.41
# 200        7       6.12      0.88
# 268        6       5.59      0.41
# 210        6       6.71     -0.71
# 906        5       5.47     -0.47
# 1093       7       6.59      0.41
# 947        7       6.59      0.41
# 867        6       6.59     -0.59

# %%
# Use predict() function to make predictions for
# training set.
knn_train_pred = knn.predict(train_X_s)

# Display common accuracy measures for training set.
print('Accuracy Measures for Training Set')
regressionSummary(train_y, knn_train_pred)
print()

# Display common accuracy measures for validation set.
print('Accuracy Measures for Validation Set')
regressionSummary(valid_y, knn_valid_pred)
# Out:
# Accuracy Measures for Training Set
#
# Regression statistics
#
#                       Mean Error (ME) : -0.0377
#        Root Mean Squared Error (RMSE) : 0.6380
#             Mean Absolute Error (MAE) : 0.4957
#           Mean Percentage Error (MPE) : -2.1602
# Mean Absolute Percentage Error (MAPE) : 9.1643
#
# Accuracy Measures for Validation Set
#
# Regression statistics
#
#                       Mean Error (ME) : -0.0188
#        Root Mean Squared Error (RMSE) : 0.6662
#             Mean Absolute Error (MAE) : 0.5361
#           Mean Percentage Error (MPE) : -1.8051
# Mean Absolute Percentage Error (MAPE) : 9.9553
